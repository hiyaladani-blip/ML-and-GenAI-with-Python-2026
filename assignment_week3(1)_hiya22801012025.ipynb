# %%
import pandas as pd

df = pd.read_csv('agriculture_yield_dataset (1).csv')

df.head()
# Out:
#    rainfall_mm  temperature_c  fertilizer_kg  irrigation_hours  soil_ph  \
# 0        588.6           18.6          242.4               6.5      6.5
# 1        772.8           34.6          247.2              10.0      6.5
# 2        970.9           36.3          168.4               7.3      6.4
# 3        611.7           19.0          121.7               3.7      6.0
# 4        696.1           29.6          184.6               5.1      6.1
#
#   crop_type soil_type  yield_ton_per_hectare
# 0     Maize     Loamy                   5.92
# 1     Maize     Sandy                   6.24
# 2     Wheat     Sandy                   4.77
# 3     Maize     Loamy                   4.04
# 4    Cotton      Clay                   5.17

# %%
df.shape
# Out:
# (1500, 8)

# %%
df.columns
# Out:
# Index(['rainfall_mm', 'temperature_c', 'fertilizer_kg', 'irrigation_hours',
#        'soil_ph', 'crop_type', 'soil_type', 'yield_ton_per_hectare'],
#       dtype='str')

# %%
df.head(10)
# Out:
#    rainfall_mm  temperature_c  fertilizer_kg  irrigation_hours  soil_ph  \
# 0        588.6           18.6          242.4               6.5      6.5
# 1        772.8           34.6          247.2              10.0      6.5
# 2        970.9           36.3          168.4               7.3      6.4
# 3        611.7           19.0          121.7               3.7      6.0
# 4        696.1           29.6          184.6               5.1      6.1
# 5        831.9           28.0          190.3               2.1      6.1
# 6       1023.8           32.0          108.5               6.9      6.2
# 7       1142.4           18.4          241.9               4.1      7.3
# 8        810.4           36.4          164.8               9.9      6.5
# 9       1085.5           29.4           89.3               8.3      5.8
#
#   crop_type soil_type  yield_ton_per_hectare
# 0     Maize     Loamy                   5.92
# 1     Maize     Sandy                   6.24
# ...

# %%
df.dtypes
# Out:
# rainfall_mm              float64
# temperature_c            float64
# fertilizer_kg            float64
# irrigation_hours         float64
# soil_ph                  float64
# crop_type                    str
# soil_type                    str
# yield_ton_per_hectare    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# rainfall_mm              0
# temperature_c            0
# fertilizer_kg            0
# irrigation_hours         0
# soil_ph                  0
# crop_type                0
# soil_type                0
# yield_ton_per_hectare    0
# dtype: int64

# %%
df.describe()
# Out:
#        rainfall_mm  temperature_c  fertilizer_kg  irrigation_hours  \
# count  1500.000000    1500.000000    1500.000000       1500.000000
# mean    754.054667      27.749467     148.744067          5.403267
# std     255.097216       5.758101      56.990279          2.584329
# min     300.200000      18.000000      50.300000          1.000000
# 25%     536.175000      22.600000      98.600000          3.200000
# 50%     761.200000      27.700000     146.850000          5.400000
# 75%     964.375000      32.600000     196.575000          7.600000
# max    1200.000000      38.000000     249.900000         10.000000
#
#            soil_ph  yield_ton_per_hectare
# count  1500.000000            1500.000000
# mean      6.759133               5.028793
# std       0.719742               0.968282
# min       5.500000               2.090000
# 25%       6.100000               4.337500
# 50%       6.800000               5.010000
# 75%       7.400000               5.740000
# ...

# %%
df.describe().loc['mean']
# Out:
# rainfall_mm              754.054667
# temperature_c             27.749467
# fertilizer_kg            148.744067
# irrigation_hours           5.403267
# soil_ph                    6.759133
# yield_ton_per_hectare      5.028793
# Name: mean, dtype: float64

# %%
df.describe().loc['std']
# Out:
# rainfall_mm              255.097216
# temperature_c              5.758101
# fertilizer_kg             56.990279
# irrigation_hours           2.584329
# soil_ph                    0.719742
# yield_ton_per_hectare      0.968282
# Name: std, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
plt.figure(figsize=(6,4))

plt.hist(df['rainfall_mm'], bins=20)

plt.title('Distribution of Rainfall')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Frequency')

plt.show()

# %%
plt.figure(figsize=(6,4))

plt.hist(df['temperature_c'], bins=20)

plt.title('Distribution of Temperature')
plt.xlabel('Temperature (°C)')
plt.ylabel('Frequency')

plt.show()

# %%
plt.figure(figsize=(6,4))

plt.hist(df['fertilizer_kg'], bins=20)

plt.title('Distribution of Fertilizer')
plt.xlabel('Fertilizer (kg)')
plt.ylabel('Frequency')

plt.show()

# %%
plt.figure(figsize=(6,4))

plt.hist(df['yield_ton_per_hectare'], bins=20)

plt.title('Distribution of Yield')
plt.xlabel('Yield (Ton/Hectare)')
plt.ylabel('Frequency')

plt.show()

# %%
df['crop_type'].value_counts()
# Out:
# crop_type
# Cotton     311
# Soybean    306
# Wheat      303
# Rice       293
# Maize      287
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    x='crop_type',
    data=df
)

plt.title('Crop Type Distribution')
plt.xlabel('Crop Type')
plt.ylabel('Count')

plt.show()

# %%
df['crop_type'].value_counts().idxmax()
# Out:
# 'Cotton'

# %%
df['soil_type'].value_counts()
# Out:
# soil_type
# Clay     534
# Sandy    492
# Loamy    474
# Name: count, dtype: int64

# %%
plt.figure(figsize=(7,5))

sns.countplot(
    x='soil_type',
    data=df
)

plt.title('Soil Type Distribution')
plt.xlabel('Soil Type')
plt.ylabel('Count')

plt.show()

# %%
df['soil_type'].value_counts().idxmax()
# Out:
# 'Clay'

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    df['yield_ton_per_hectare'],
    bins=20,
    kde=True
)

plt.title('Yield Distribution')
plt.xlabel('Yield (Ton per Hectare)')
plt.ylabel('Frequency')

plt.show()

# %%
print("Yes, the distribution appears approximately normal because it is centered around the mean and resembles a bell-shaped curve.""agriculture_yield_dataset (1).csv")
print("No significant outliers are visible in the distribution. Most values are clustered around the center with a gradual decrease toward both ends.""agriculture_yield_dataset (1).csv")
# Out:
# Yes, the distribution appears approximately normal because it is centered around the mean and resembles a bell-shaped curve.agriculture_yield_dataset (1).csv
# No significant outliers are visible in the distribution. Most values are clustered around the center with a gradual decrease toward both ends.agriculture_yield_dataset (1).csv

# %%
plt.figure(figsize=(8,5))

plt.scatter(
    df['rainfall_mm'],
    df['yield_ton_per_hectare']
)

plt.title('Rainfall vs Yield')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Yield (Ton per Hectare)')

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(
    df['fertilizer_kg'],
    df['yield_ton_per_hectare']
)

plt.title('Fertilizer vs Yield')
plt.xlabel('Fertilizer (kg)')
plt.ylabel('Yield (Ton per Hectare)')

plt.show()

# %%
print("Rainfall appears to have a stronger positive relationship with crop yield than fertilizer. As rainfall increases, crop yield tends to increase more consistently, whereas fertilizer shows a weaker trend.")
# Out:
# Rainfall appears to have a stronger positive relationship with crop yield than fertilizer. As rainfall increases, crop yield tends to increase more consistently, whereas fertilizer shows a weaker trend.

# %%
import numpy as np

numeric_df = df.select_dtypes(include=np.number)

# %%
corr_matrix = numeric_df.corr()

corr_matrix
# Out:
#                        rainfall_mm  temperature_c  fertilizer_kg  \
# rainfall_mm               1.000000       0.026721       0.002558
# temperature_c             0.026721       1.000000       0.037468
# fertilizer_kg             0.002558       0.037468       1.000000
# irrigation_hours          0.010877       0.007114      -0.010497
# soil_ph                   0.006916       0.001513       0.010001
# yield_ton_per_hectare     0.553704      -0.022559       0.278043
#
#                        irrigation_hours   soil_ph  yield_ton_per_hectare
# rainfall_mm                    0.010877  0.006916               0.553704
# temperature_c                  0.007114  0.001513              -0.022559
# fertilizer_kg                 -0.010497  0.010001               0.278043
# irrigation_hours               1.000000  0.009307               0.542664
# soil_ph                        0.009307  1.000000               0.024412
# yield_ton_per_hectare          0.542664  0.024412               1.000000

# %%
plt.figure(figsize=(10,8))

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap='coolwarm'
)

plt.title('Correlation Heatmap')

plt.show()

# %%
corr_matrix['yield_ton_per_hectare'].sort_values(ascending=False)
# Out:
# yield_ton_per_hectare    1.000000
# rainfall_mm              0.553704
# irrigation_hours         0.542664
# fertilizer_kg            0.278043
# soil_ph                  0.024412
# temperature_c           -0.022559
# Name: yield_ton_per_hectare, dtype: float64

# %%
crop_yield = df.groupby('crop_type')['yield_ton_per_hectare'].mean()

crop_yield
# Out:
# crop_type
# Cotton     4.607299
# Maize      4.897143
# Rice       5.494744
# Soybean    5.173431
# Wheat      4.989472
# Name: yield_ton_per_hectare, dtype: float64

# %%
crop_yield.idxmax()
# Out:
# 'Rice'

# %%
soil_yield = df.groupby('soil_type')['yield_ton_per_hectare'].mean()

soil_yield
# Out:
# soil_type
# Clay     5.134326
# Loamy    5.366519
# Sandy    4.588882
# Name: yield_ton_per_hectare, dtype: float64

# %%
soil_yield.idxmax()
# Out:
# 'Loamy'

# %%
df.select_dtypes(include='object').columns
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_2148\3732952691.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.select_dtypes(include='object').columns
# Index(['crop_type', 'soil_type'], dtype='str')

# %%
df_encoded = pd.get_dummies(
    df,
    columns=['crop_type', 'soil_type'],
    drop_first=True
)

# %%
df_encoded.head()
# Out:
#    rainfall_mm  temperature_c  fertilizer_kg  irrigation_hours  soil_ph  \
# 0        588.6           18.6          242.4               6.5      6.5
# 1        772.8           34.6          247.2              10.0      6.5
# 2        970.9           36.3          168.4               7.3      6.4
# 3        611.7           19.0          121.7               3.7      6.0
# 4        696.1           29.6          184.6               5.1      6.1
#
#    yield_ton_per_hectare  crop_type_Maize  crop_type_Rice  crop_type_Soybean  \
# 0                   5.92             True           False              False
# 1                   6.24             True           False              False
# 2                   4.77            False           False              False
# 3                   4.04             True           False              False
# 4                   5.17            False           False              False
#
#    crop_type_Wheat  soil_type_Loamy  soil_type_Sandy
# ...

# %%
df_encoded.head()
# Out:
#    rainfall_mm  temperature_c  fertilizer_kg  irrigation_hours  soil_ph  \
# 0        588.6           18.6          242.4               6.5      6.5
# 1        772.8           34.6          247.2              10.0      6.5
# 2        970.9           36.3          168.4               7.3      6.4
# 3        611.7           19.0          121.7               3.7      6.0
# 4        696.1           29.6          184.6               5.1      6.1
#
#    yield_ton_per_hectare  crop_type_Maize  crop_type_Rice  crop_type_Soybean  \
# 0                   5.92             True           False              False
# 1                   6.24             True           False              False
# 2                   4.77            False           False              False
# 3                   4.04             True           False              False
# 4                   5.17            False           False              False
#
#    crop_type_Wheat  soil_type_Loamy  soil_type_Sandy
# ...

# %%
df_encoded.shape
# Out:
# (1500, 12)

# %%
X = df_encoded.drop(
    'yield_ton_per_hectare',
    axis=1
)

# %%
y = df_encoded['yield_ton_per_hectare']

# %%
X.head()
# Out:
#    rainfall_mm  temperature_c  fertilizer_kg  irrigation_hours  soil_ph  \
# 0        588.6           18.6          242.4               6.5      6.5
# 1        772.8           34.6          247.2              10.0      6.5
# 2        970.9           36.3          168.4               7.3      6.4
# 3        611.7           19.0          121.7               3.7      6.0
# 4        696.1           29.6          184.6               5.1      6.1
#
#    crop_type_Maize  crop_type_Rice  crop_type_Soybean  crop_type_Wheat  \
# 0             True           False              False            False
# 1             True           False              False            False
# 2            False           False              False             True
# 3             True           False              False            False
# 4            False           False              False            False
#
#    soil_type_Loamy  soil_type_Sandy
# 0             True            False
# ...

# %%
y.head()
# Out:
# 0    5.92
# 1    6.24
# 2    4.77
# 3    4.04
# 4    5.17
# Name: yield_ton_per_hectare, dtype: float64

# %%
print("X Shape:", X.shape)
print("y Shape:", y.shape)
# Out:
# X Shape: (1500, 11)
# y Shape: (1500,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
print("y_train shape:", y_train.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (1200, 11)
# X_test shape: (300, 11)
# y_train shape: (1200,)
# y_test shape: (300,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("Intercept:", model.intercept_)
# Out:
# Intercept: 1.587132027736125

# %%
coef_df = pd.DataFrame({
    'Feature': X.columns,
    'Coefficient': model.coef_
})

coef_df
# Out:
#               Feature  Coefficient
# 0         rainfall_mm     0.002035
# 1       temperature_c    -0.009175
# 2       fertilizer_kg     0.004978
# 3    irrigation_hours     0.198327
# 4             soil_ph     0.004901
# 5     crop_type_Maize     0.238931
# 6      crop_type_Rice     0.863993
# 7   crop_type_Soybean     0.481719
# 8     crop_type_Wheat     0.348474
# 9     soil_type_Loamy     0.302974
# 10    soil_type_Sandy    -0.490933

# %%
coef_df.sort_values(
    by='Coefficient',
    ascending=False
)
# Out:
#               Feature  Coefficient
# 6      crop_type_Rice     0.863993
# 7   crop_type_Soybean     0.481719
# 8     crop_type_Wheat     0.348474
# 9     soil_type_Loamy     0.302974
# 5     crop_type_Maize     0.238931
# 3    irrigation_hours     0.198327
# 2       fertilizer_kg     0.004978
# 4             soil_ph     0.004901
# 0         rainfall_mm     0.002035
# 1       temperature_c    -0.009175
# 10    soil_type_Sandy    -0.490933

# %%
coef_df.loc[
    coef_df['Coefficient'].idxmax()
]
# Out:
# Feature        crop_type_Rice
# Coefficient          0.863993
# Name: 6, dtype: object

# %%
print("The feature with the highest positive coefficient is crop_type_Rice.")
# Out:
# The feature with the highest positive coefficient is crop_type_Rice.
